# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LATITUDE_FORMATTER, LONGITUDE_FORMATTER
import cftime
import datetime
from datetime import date
from matplotlib import pyplot
from matplotlib import colors
from matplotlib import font_manager
from matplotlib.cm import ScalarMappable
import matplotlib.colors as mcolors
import matplotlib.dates as mdates
import matplotlib.lines as mlines
import matplotlib.patches as mpatches
import matplotlib.ticker as mticker
import numpy
import pandas
from PIL import Image
import random
import xarray as xr

# %%
Diri = '/glade/u/home/whimkao//ExtraTrack/ExtraTrack_Data/Output_Files_V6/'
Output_Diri = '/glade/u/home/whimkao//ExtraTrack/ExtraTrack_Github/RCP_Figs/Analysis_Figs_V6.4.3/'

# %%
# Open File
def Open_File(File):
    DF = pandas.read_csv(File)
    DF = DF.drop("Unnamed: 0", axis=1)
    return (DF)

# %%
# Open Each File
def Files_Open(Model, Diri):
    Data_DF = Open_File(Diri+Model+'_Data_hPa_Output_V6.csv')
    ET_DF = Open_File(Diri+Model+'_ET_hPa_Output_V6.csv')
    Codes_DF = Open_File(Diri+Model+'_Codes_Output_V6.csv')
    Time, Begin_Time, Compl_Time, Peak_Time = [], [], [], []
# Edit Time Format
    for i in range(len(Data_DF)):
        Time.append(Datetime(Data_DF["Time(Z)"][i]))
    for j in range(len(ET_DF)):
        Begin_Time.append(Datetime(ET_DF["ET Begin Time"][j]))
        Compl_Time.append(Datetime(ET_DF["ET Complete Time"][j]))
        Peak_Time.append(Datetime(ET_DF["Peak Time"][j]))
    Data_DF["Time(Z)"] = Time
    ET_DF["ET Begin Time"] = Begin_Time
    ET_DF["ET Complete Time"] = Compl_Time
    ET_DF["Peak Time"] = Peak_Time
    return (Data_DF, ET_DF, Codes_DF)

# %%
def Datetime(Time):
    try:
        New_Time = datetime.datetime.strptime(Time, '%Y-%m-%d %H:%M:%S')
    except:
        New_Time = numpy.nan
    return (New_Time)

# %%
# Create Phase Distribution Bins
def Create_Bins(Min, Max, Bin_Width):
    Bins = numpy.arange(Min, Max+Bin_Width, Bin_Width)
    return (Bins)
Lat_Bins = Create_Bins(10,60,5)
Lon_Bins = Create_Bins(-100,20,5)

# %%
Num_Years = numpy.array([90,93,93])

# %%
Control_Data, Control_ET, Control_Codes = Files_Open("Control", Diri)
RCP45_Data, RCP45_ET, RCP45_Codes = Files_Open("RCP45", Diri)
RCP85_Data, RCP85_ET, RCP85_Codes = Files_Open("RCP85", Diri)

# %%
# Create Function to Plot ET Begin and Complete Locations
def Plot_ET_Locs(ET_DF, Model, i, Begin):
#
# Plot ET Begin Locations
    if Begin == True:
        Axis = Fig.add_subplot(3,1,i+1, projection=ccrs.PlateCarree())
        Begin_Lons = ET_DF["ET Begin Lon"]
        Begin_Lats = ET_DF["ET Begin Lat"]
        for k in range(len(Begin_Lats)):
            pyplot.scatter(Begin_Lons[k], Begin_Lats[k], marker='s', linewidths=1.8, \
            facecolors='none', edgecolors='black', s=28)
        Plot_Map_Formatting(Axis)
        Title = Model + " -- ET Initiation Locations"
        Axis.set_title(Title, fontsize=18)
#
# Plot ET Complete Data
    else:
        Axis = Fig.add_subplot(3,1,i+1, projection=ccrs.PlateCarree())
        Compl_Lons = ET_DF["ET Complete Lon"]
        Compl_Lats = ET_DF["ET Complete Lat"]
        for k in range(len(Compl_Lats)):
            pyplot.scatter(Compl_Lons[k], Compl_Lats[k], marker='^', linewidths=1.8, \
            facecolors='none', edgecolors='black', s=28)
        Plot_Map_Formatting(Axis)
        Title = Model + " -- ET Completion Locations"
        Axis.set_title(Title, fontsize=18)

# %%
def Plot_Map_Formatting(Axis):
    Axis.coastlines(linewidth=0.5)
    Axis.add_feature(cfeature.BORDERS, linewidth=0.5)
    Axis.add_feature(cfeature.STATES, linewidth=0.3)
    x_Min, x_Max, y_Min, y_Max = -100, 20, 10, 60
    x_Axis = Create_Bins(x_Min, x_Max, 10)
    y_Axis = Create_Bins(y_Min, y_Max, 10)
    Axis.set_xticks(x_Axis)
    Axis.set_yticks(y_Axis)
    Axis.set_xlim(x_Min,x_Max)
    Axis.set_ylim(y_Min,y_Max)
    Gridline = Axis.grid(linewidth=0.3, color='silver', linestyle='-')

# %%
# Plot ET Initiation Locations
Fig = pyplot.figure(figsize=(12,16))
Plot_ET_Locs(Control_ET, "Control", 0, True)
Plot_ET_Locs(RCP45_ET, "RCP4.5", 1, True)
Plot_ET_Locs(RCP85_ET, "RCP8.5", 2, True)
Fig.tight_layout()

# %%
# Plot ET Completion Locations
Fig = pyplot.figure(figsize=(12,16))
Plot_ET_Locs(Control_ET, "Control", 0, False)
Plot_ET_Locs(RCP45_ET, "RCP4.5", 1, False)
Plot_ET_Locs(RCP85_ET, "RCP8.5", 2, False)
Fig.tight_layout()

# %%
# Create Subsets

# %%
Fig = pyplot.figure(figsize=(12,8))
Axis = Fig.add_subplot(1,1,1, projection=ccrs.PlateCarree())
Axis.coastlines(linewidth=0.5)
Axis.add_feature(cfeature.BORDERS, linewidth=0.5)
Axis.add_feature(cfeature.STATES, linewidth=0.3)
x_Min, x_Max, y_Min, y_Max = -90,-50,25,55
x_Axis = Create_Bins(x_Min, x_Max, 5)
y_Axis = Create_Bins(y_Min, y_Max, 5)
pyplot.xticks(x_Axis)
pyplot.yticks(y_Axis)
pyplot.xlim(x_Min,x_Max)
pyplot.ylim(y_Min,y_Max)
pyplot.grid(linewidth=0.3, color='silver', linestyle='-')
#
pyplot.plot(\
[-90,-83,-83,-82,-82,-80,-80,-78,-78,-76,-76,-72,-72,-68,-68,-62,-62], \
[31,31,33,33,34,34,36,36,40,40,43,43,46,46,52,52,55], c='black', linewidth=2.8)

# %%
def Subset_ET_Begin_Loc(ET_Orig):
    ET = ET_Orig[ET_Orig["ET Begin Lat"] >= 20]
    ET = ET[(ET["ET Begin Lat"] <= 31) | (ET["ET Begin Lon"] > -83)]
    ET = ET[(ET["ET Begin Lat"] <= 33) | (ET["ET Begin Lon"] > -82)]
    ET = ET[(ET["ET Begin Lat"] <= 34) | (ET["ET Begin Lon"] > -80)]
    ET = ET[(ET["ET Begin Lat"] <= 36) | (ET["ET Begin Lon"] > -78)]
    ET = ET[(ET["ET Begin Lat"] <= 40) | (ET["ET Begin Lon"] > -76)]
    ET = ET[(ET["ET Begin Lat"] <= 43) | (ET["ET Begin Lon"] > -72)]
    ET = ET[(ET["ET Begin Lat"] <= 46) | (ET["ET Begin Lon"] > -68)]
    ET = ET[(ET["ET Begin Lat"] <= 52) | (ET["ET Begin Lon"] > -62)]
    ET_Output = ET.reset_index().drop("index", axis=1)
    return (ET_Output)

# %%
print (len(Control_ET), len(RCP45_ET), len(RCP85_ET))
# Out:
# 248 163 169

# %%
Control_ET_V1 = Subset_ET_Begin_Loc(Control_ET)
RCP45_ET_V1 = Subset_ET_Begin_Loc(RCP45_ET)
RCP85_ET_V1 = Subset_ET_Begin_Loc(RCP85_ET)

# %%
print (len(Control_ET_V1), len(RCP45_ET_V1), len(RCP85_ET_V1))
# Out:
# 219 144 154

# %%
# Plot ET Initiation Locations
Fig = pyplot.figure(figsize=(12,16))
Plot_ET_Locs(Control_ET_V1, "Control", 0, True)
Plot_ET_Locs(RCP45_ET_V1, "RCP4.5", 1, True)
Plot_ET_Locs(RCP85_ET_V1, "RCP8.5", 2, True)
Fig.tight_layout()

# %%
def Subset_ET_Complete_Loc(ET_Orig):
    ET = ET_Orig[ET_Orig["ET Complete Lat"] >= 25]
    ET = ET[(ET["ET Complete Lat"] <= 31) | (ET["ET Complete Lon"] > -83)]
    ET = ET[(ET["ET Complete Lat"] <= 33) | (ET["ET Complete Lon"] > -82)]
    ET = ET[(ET["ET Complete Lat"] <= 34) | (ET["ET Complete Lon"] > -80)]
    ET = ET[(ET["ET Complete Lat"] <= 36) | (ET["ET Complete Lon"] > -78)]
    ET = ET[(ET["ET Complete Lat"] <= 40) | (ET["ET Complete Lon"] > -76)]
    ET = ET[(ET["ET Complete Lat"] <= 43) | (ET["ET Complete Lon"] > -72)]
    ET = ET[(ET["ET Complete Lat"] <= 46) | (ET["ET Complete Lon"] > -68)]
    ET = ET[(ET["ET Complete Lat"] <= 52) | (ET["ET Complete Lon"] > -62)]
    ET_Output = ET.reset_index().drop("index", axis=1)
    return (ET_Output)

# %%
Control_ET_V2 = Subset_ET_Complete_Loc(Control_ET_V1)
RCP45_ET_V2 = Subset_ET_Complete_Loc(RCP45_ET_V1)
RCP85_ET_V2 = Subset_ET_Complete_Loc(RCP85_ET_V1)

# %%
print (len(Control_ET_V2), len(RCP45_ET_V2), len(RCP85_ET_V2))
# Out:
# 208 139 150

# %%
# Plot ET Completion Locations
Fig = pyplot.figure(figsize=(12,16))
Plot_ET_Locs(Control_ET_V2, "Control", 0, False)
Plot_ET_Locs(RCP45_ET_V2, "RCP4.5", 1, False)
Plot_ET_Locs(RCP85_ET_V2, "RCP8.5", 2, False)
Fig.tight_layout()

# %%
# Plot ET Initiation Locations
Fig = pyplot.figure(figsize=(12,16))
Plot_ET_Locs(Control_ET_V2, "Control", 0, True)
Plot_ET_Locs(RCP45_ET_V2, "RCP4.5", 1, True)
Plot_ET_Locs(RCP85_ET_V2, "RCP8.5", 2, True)
Fig.tight_layout()
